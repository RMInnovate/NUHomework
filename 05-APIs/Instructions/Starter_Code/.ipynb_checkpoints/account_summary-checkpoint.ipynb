# %% [markdown]
# # Budget Analysis
#
# ---
#
# ## Environment Setup

# %%
# Initial Imports
import os
import plaid
import requests
import datetime
import json
import pandas as pd
from dotenv import load_dotenv
from pathlib import Path
import hvplot.pandas

# %matplotlib inline

# %%
# Helper functions

def pretty_print_response(response):
    """
    This function formats a JSON file to pretty printing it in the screen.
    """
    print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Set environment variables from the .env file
rel_path = Path('../../../../Python') / '.env'
load_dotenv(rel_path)
# Out:
# True

# %%
# Extract API keys from environment variables
PLAID_CLIENT_ID = os.getenv("PLAID_CLIENT_ID")
PLAID_SECRET = os.getenv("PLAID_SBX_SECRET_KEY")
PLAID_PUBLIC_KEY = os.getenv("PLAID_PUBLIC_KEY")

# %% [markdown]
# ---
#
# ## Plaid Access Token
#
# In this section, you will use the `plaid-python` API to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
#
# 1. Create a client to connect to plaid
#
# 2. Use the client to generate a public token and request the following items: ['transactions', 'income', 'assets']
#
# 3. Exchange the public token for an access token
#
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
# Create the client object
client = plaid.Client(client_id=PLAID_CLIENT_ID, secret=PLAID_SECRET, public_key=PLAID_PUBLIC_KEY, environment='sandbox')

# Get institutions
client.Institutions.get(1)
# Out:
# {'institutions': [{'country_codes': ['US'],
#    'credentials': [{'label': 'Username', 'name': 'username', 'type': 'text'},
#     {'label': 'Password', 'name': 'password', 'type': 'password'}],
#    'has_mfa': True,
#    'input_spec': 'fixed',
#    'institution_id': 'ins_112060',
#    'mfa': ['code', 'list', 'questions', 'selections'],
#    'mfa_code_type': 'numeric',
#    'name': '1st Bank (Broadus, MT) - Personal',
#    'oauth': False,
#    'products': ['assets',
#     'auth',
#     'balance',
#     'transactions',
#     'income',
#     'identity'],
#    'routing_numbers': []}],
#  'request_id': 'ZW6fJACYFXIh2di',
#  'total': 11384}

# %%
# Set the institution id
INSTITUTION_ID = "ins_109508"

# %% [markdown]
# ### 2. Generate a public token

# %%
# Create the public token
create_tkn_response = client.Sandbox.public_token.create(INSTITUTION_ID, ['transactions','income','assets'])

# Print the public token
create_tkn_response
# Out:
# {'public_token': 'public-sandbox-64a7180c-06b0-4708-b210-b5ed0a139d75',
#  'request_id': 'AXSSRdD56qTKipx'}

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# Exchange public token for access token
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])

# Store the access token in a Python variable
access_token = exchange_response['access_token']

# Print the access toke
access_token
# Out:
# 'access-sandbox-75c8e606-e98c-4931-9e80-729ac870c6e1'

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# Retrieve accounts
client.Accounts.get(access_token)

# Print accounts
# Out:
# {'accounts': [{'account_id': 'aMzD1qPVv6ILaZPg9ngGc9Jb878a6NT7QJXN8',
#    'balances': {'available': 100,
#     'current': 110,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '0000',
#    'name': 'Plaid Checking',
#    'official_name': 'Plaid Gold Standard 0% Interest Checking',
#    'subtype': 'checking',
#    'type': 'depository'},
#   {'account_id': '4K9mxWp8NnsPJkeKwLKvCPWn7Q7ywMtdAVmoB',
#    'balances': {'available': 200,
#     'current': 210,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '1111',
#    'name': 'Plaid Saving',
#    'official_name': 'Plaid Silver Standard 0.1% Interest Saving',
#    'subtype': 'savings',
#    'type': 'depository'},
#   {'account_id': 'NGoXlZM1v8SpgMGJA4Jdfl56DeDg1yFW5pV3g',
#    'balances': {'available': None,
#     'current': 1000,
#     'iso_currency_code': 'USD',
#     'limit': None,
# ...

# %% [markdown]
# ---
#
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
#
# 2. Print the categories for each transaction type
#
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
#
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# Set the start and end date 90 days from today
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now())

# Retrieve the transactions for the last 90 days
transaction_response = client.Transactions.get(access_token,start_date,end_date)

# Print the transactions
print(json.dumps(transaction_response['transactions'][:2],indent=4, sort_keys=True))
# Out:
# [
#     {
#         "account_id": "Pq8VK1jpvkfgrZ1mqPmRI35Vj1jryNs7W5K1r",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-05-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Tectra Inc",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
# ...

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# Create a for-loop to print the categories for each transaction
count=0
for transactions in transaction_response['transactions']:
    per_category = transactions['category']
    print(f'For Transaction {count}, the categories are {per_category}')
    count+=1
# Out:
# For Transaction 0, the categories are ['Food and Drink', 'Restaurants']
# For Transaction 1, the categories are ['Payment']
# For Transaction 2, the categories are ['Food and Drink', 'Restaurants', 'Fast Food']
# For Transaction 3, the categories are ['Shops', 'Sporting Goods']
# For Transaction 4, the categories are ['Payment', 'Credit Card']
# For Transaction 5, the categories are ['Travel', 'Taxi']
# For Transaction 6, the categories are ['Transfer', 'Debit']
# For Transaction 7, the categories are ['Transfer', 'Deposit']
# For Transaction 8, the categories are ['Recreation', 'Gyms and Fitness Centers']
# For Transaction 9, the categories are ['Travel', 'Airlines and Aviation Services']
# For Transaction 10, the categories are ['Food and Drink', 'Restaurants', 'Fast Food']
# For Transaction 11, the categories are ['Food and Drink', 'Restaurants', 'Coffee Shop']
# For Transaction 12, the categories are ['Food and Drink', 'Restaurants']
# ...

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: `date`, `name`, `amount`, `category`.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# Define an empty DataFrame and set the columns as date, name, amount, and category
df=pd.DataFrame(data=None, columns=['Date', 'Name', 'Amount', 'Category'])

# Retrieve all the transactions
# Populate the transactions DataFrame with the transactions data
count=0
for transactions in transaction_response['transactions']:
    per_date = transactions['date']
    per_name = transactions['name']
    per_amount = transactions['amount']
    per_category = transactions['category'][0]
    df.loc[count]=[per_date, per_name, per_amount, per_category]
    count+=1

# Display sample data from the DataFrame    
df
# Out:
#           Date                                   Name  Amount        Category
# 0   2020-05-25                             Tectra Inc     500  Food and Drink
# 1   2020-05-24              AUTOMATIC PAYMENT - THANK  2078.5         Payment
# 2   2020-05-24                                    KFC     500  Food and Drink
# 3   2020-05-24                   Madison Bicycle Shop     500           Shops
# 4   2020-05-15           CREDIT CARD 3333 PAYMENT *//      25         Payment
# 5   2020-05-15                                   Uber     5.4          Travel
# 6   2020-05-14  ACH Electronic CreditGUSTO PAY 123456    5850        Transfer
# 7   2020-05-14                   CD DEPOSIT .INITIAL.    1000        Transfer
# 8   2020-05-13                    Touchstone Climbing    78.5      Recreation
# 9   2020-05-13                        United Airlines    -500          Travel
# 10  2020-05-12                             McDonald's      12  Food and Drink
# ...

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# Display data types
#type(df['Date'][0])
type(df.Date.loc[0])
# Out:
# str

# %%
#type(df['Name'][0])
type(df.Name.loc[0])
# Out:
# str

# %%
#type(df['Amount'][1])
type(df.Amount.loc[0])
# Out:
# int

# %%
type(df['Category'][0])
type(df.Category.loc[2])
# Out:
# str

# %%
# Make any required data type transformation
# Convert the Amount data to float
df.Amount = df.Amount.astype(float)
type(df.Amount.loc[0])
# Out:
# numpy.float64

# %%
# Set the date column as index
df.set_index('Date', inplace=True)

# Display sample data
df
# Out:
#                                              Name   Amount        Category
# Date
# 2020-05-25                             Tectra Inc   500.00  Food and Drink
# 2020-05-24              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 2020-05-24                                    KFC   500.00  Food and Drink
# 2020-05-24                   Madison Bicycle Shop   500.00           Shops
# 2020-05-15           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 2020-05-15                                   Uber     5.40          Travel
# 2020-05-14  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 2020-05-14                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 2020-05-13                    Touchstone Climbing    78.50      Recreation
# 2020-05-13                        United Airlines  -500.00          Travel
# 2020-05-12                             McDonald's    12.00  Food and Drink
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
#
# 1. Determine the previous year's gross income and print the results
#
# 2. Determine the current monthly income and print the results
#
# 3. Determine the projected yearly income and print the results

# %%
# Fetch de income data
income_response = client.Income.get(access_token)

# Print the income data
print(json.dumps(income_response['income'],indent=4, sort_keys=True))
# Out:
# {
#     "income_streams": [
#         {
#             "confidence": 0.99,
#             "days": 690,
#             "monthly_income": 500,
#             "name": "UNITED AIRLINES"
#         }
#     ],
#     "last_year_income": 6000,
#     "last_year_income_before_tax": 7285,
#     "max_number_of_overlapping_income_streams": 1,
#     "number_of_income_streams": 1,
#     "projected_yearly_income": 6085,
#     "projected_yearly_income_before_tax": 7389
# }

# %%
# Determine the previous year's gross income and print the results
per_last_year_income = income_response['income']['last_year_income']
str_last_year_income = '${:,.2f}'.format(per_last_year_income)
print(f'The last year income is {str_last_year_income}.')
# Out:
# The last year income is $6,000.00.

# %%
# Determine the current monthly income and print the results
per_monthly_income = income_response['income']['income_streams'][0]['monthly_income']
str_monthly_income = '${:,.2f}'.format(per_monthly_income)
print(f'The monthly income is {str_monthly_income}.')
# Out:
# The monthly income is $500.00.

# %%
# Determine the projected yearly income and print the results
per_projected_yearly_income = income_response['income']['projected_yearly_income']
str_projected_yearly_income = '${:,.2f}'.format(per_projected_yearly_income)
print(f'The projected yearly income is {str_projected_yearly_income}.')
# Out:
# The projected yearly income is $6,085.00.

# %% [markdown]
# ---

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
#
# 2. Generate a bar chart with the number of transactions for each category
#
# 3. Calulate the expenses per month
#
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
# Compute the total expenses per category
total_expense_per_category = df.groupby("Category").sum()

# Display the expenses per catefory
total_expense_per_category
# Out:
#                   Amount
# Category
# Food and Drink   3317.19
# Payment          6310.50
# Recreation        235.50
# Shops            1500.00
# Transfer        20537.34
# Travel             35.19

# %%
# Create a spending categories pie chart.
total_expense_per_category.plot.pie(subplots=True, legend=False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f8ee3298950>],
#       dtype=object)

# %% [markdown]
# ### Calculate the expenses per month

# %%
# Create a DataFrame with the total expenses
df_expense_only=df.drop(columns=['Name','Category'])
# Display sample data
df_expense_only
# Out:
#              Amount
# Date
# 2020-05-25   500.00
# 2020-05-24  2078.50
# 2020-05-24   500.00
# 2020-05-24   500.00
# 2020-05-15    25.00
# 2020-05-15     5.40
# 2020-05-14  5850.00
# 2020-05-14  1000.00
# 2020-05-13    78.50
# 2020-05-13  -500.00
# 2020-05-12    12.00
# 2020-05-12     4.33
# 2020-05-11    89.40
# 2020-05-10    -4.22
# 2020-04-30   500.00
# 2020-04-28     6.33
# 2020-04-25   500.00
# 2020-04-24  2078.50
# 2020-04-24   500.00
# 2020-04-24   500.00
# 2020-04-15    25.00
# 2020-04-15     5.40
# 2020-04-14  5850.00
# 2020-04-14  1000.00
# 2020-04-13    78.50
# 2020-04-13  -500.00
# 2020-04-12    12.00
# 2020-04-12     4.33
# 2020-04-11    89.40
# 2020-04-10    -4.22
# 2020-03-31   500.00
# 2020-03-29     6.33
# 2020-03-26   500.00
# 2020-03-25  2078.50
# 2020-03-25   500.00
# 2020-03-25   500.00
# 2020-03-16    25.00
# 2020-03-16     5.40
# 2020-03-15  5850.00
# 2020-03-15  1000.00
# 2020-03-14    78.50
# 2020-03-14  -500.00
# 2020-03-13    12.00
# 2020-03-13     4.33
# ...

# %%
# Create a spending per month bar chart
df_expense_only.index = pd.to_datetime(df_expense_only.index)
monthly_expense = df_expense_only.groupby(by=[df_expense_only.index.month]).sum()

monthly_expense
# Out:
#         Amount
# Date
# 2         6.33
# 3     11145.24
# 4     10645.24
# 5     10138.91

# %%
monthly_expense.hvplot.bar(xlabel="Month", rot=90)
# Out:
# :Bars   [Date]   (Amount)
