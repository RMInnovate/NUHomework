# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("Resources/whale_returns.csv")

whale_df = pd.read_csv(whale_returns_csv, index_col='Date', parse_dates=True, infer_datetime_format=True)
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("Resources/algo_returns.csv")

algo_df = pd.read_csv(algo_returns_csv, index_col='Date', parse_dates=True, infer_datetime_format=True)
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace=True)
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("Resources/sp500_history.csv")

sp500_df = pd.read_csv(sp500_history_csv, index_col='Date', parse_dates=True, infer_datetime_format=True)

sp500_df.sort_index(ascending=True, inplace=True)
sp500_df
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93
# ...              ...
# 2019-04-16  $2907.06
# 2019-04-17  $2900.45
# 2019-04-18  $2905.03
# 2019-04-22  $2907.97
# 2019-04-23  $2933.68
#
# [1649 rows x 1 columns]

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df['Close'] = sp500_df['Close'].str.replace('$', '').astype('float')
sp500_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns and Drop Nulls
sp500_returns_df = sp500_df.pct_change().dropna()
sp500_returns_df
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %%
# Rename Column
sp500_returns_df.rename({'Close':'S&P 500'}, axis=1, inplace=True)
sp500_returns_df
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat([whale_df, algo_df, sp500_returns_df], axis='columns', join='inner')
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# ...                                 ...                     ...       ...
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# 2015-03-06 -0.011460 -0.014174
# 2015-03-09  0.001303  0.003944
# ...              ...       ...
# 2019-04-16  0.002899  0.000509
# 2019-04-17 -0.005228 -0.002274
# 2019-04-18 -0.001229  0.001579
# 2019-04-22 -0.001936  0.001012
# 2019-04-23  0.009622  0.008841
#
# [1043 rows x 7 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?

# %%
# Plot daily returns
combined_df.plot(figsize=(20,10))

# %%
# Plot cumulative returns
(1 + combined_df).cumprod().plot(figsize=(20,10))

# %% [markdown]
# ---

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
combined_df.plot(kind='box', figsize=(20,10))

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
# Which portfolios are riskier than the S&P 500?
std_df = combined_df.std()
std_df
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
std_df.gt(std_df['S&P 500'])
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# dtype: bool

# %%
# Calculate the annualized standard deviation (252 trading days)
annual_std_df = combined_df.std() * np.sqrt(252)
annual_std_df
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P 500                        0.135786
# dtype: float64

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# 2. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window
combined_df.rolling(window=21).std().plot(figsize=(20,10))

# %%
#Calculate covariance per portfolio
corr_df = combined_df.cov()
corr_df

# soros_covariance_df = combined_df.loc(1)#.cov(combined_df['S&P 500'])
# soros_covariance_df

#soros_covariance_df = combined_df['SOROS FUND MANAGEMENT LLC'].cov(combined_df['S&P 500'])
#soros_covariance_df
# paul_covariance_df = combined_df['PAULSON & CO.INC.'].cov(combined_df['S&P 500'])
# paul_covariance_df
# tiger_covariance_df = combined_df['TIGER GLOBAL MANAGEMENT LLC'].cov(combined_df['S&P 500'])
# tiger_covariance_df
# berk_covariance_df = combined_df['BERKSHIRE HATHAWAY INC'].cov(combined_df['S&P 500'])
# berk_covariance_df
# algo1_covariance_df = combined_df['Algo 1'].cov(combined_df['S&P 500'])
# algo1_covariance_df
# algo2_covariance_df = combined_df['Algo 2'].cov(combined_df['S&P 500'])
# algo2_covariance_df

# # Calculate variance of all daily returns vs. S&P 500
# variance = combined_df['S&P 500'].var()
# variance
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     0.000062            0.000039
# PAULSON & CO.INC.                             0.000039            0.000049
# TIGER GLOBAL MANAGEMENT LLC                   0.000048            0.000033
# BERKSHIRE HATHAWAY INC                        0.000077            0.000050
# Algo 1                                        0.000019            0.000014
# Algo 2                                        0.000054            0.000040
# S&P 500                                       0.000057            0.000040
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.000048
# PAULSON & CO.INC.                               0.000033
# TIGER GLOBAL MANAGEMENT LLC                     0.000119
# BERKSHIRE HATHAWAY INC                          0.000060
# Algo 1                                          0.000014
# Algo 2                                          0.000046
# S&P 500                                         0.000058
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.000077  0.000019  0.000054
# PAULSON & CO.INC.                          0.000050  0.000014  0.000040
# TIGER GLOBAL MANAGEMENT LLC                0.000060  0.000014  0.000046
# BERKSHIRE HATHAWAY INC                     0.000167  0.000029  0.000074
# Algo 1                                     0.000029  0.000058  0.000018
# Algo 2                                     0.000074  0.000018  0.000070
# S&P 500                                    0.000083  0.000018  0.000061
#
#                               S&P 500
# SOROS FUND MANAGEMENT LLC    0.000057
# PAULSON & CO.INC.            0.000040
# TIGER GLOBAL MANAGEMENT LLC  0.000058
# BERKSHIRE HATHAWAY INC       0.000083
# Algo 1                       0.000018
# Algo 2                       0.000061
# S&P 500                      0.000073

# %%
# Calculate variance of all daily returns vs. S&P 500
variance = combined_df['S&P 500'].var()
variance
# Out:
# 7.316632424648712e-05

# %%
beta_df = corr_df / variance
beta_df
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     0.851989            0.530437
# PAULSON & CO.INC.                             0.530437            0.674130
# TIGER GLOBAL MANAGEMENT LLC                   0.659779            0.454330
# BERKSHIRE HATHAWAY INC                        1.051613            0.676589
# Algo 1                                        0.264131            0.196642
# Algo 2                                        0.744362            0.543035
# S&P 500                                       0.773375            0.549886
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.659779
# PAULSON & CO.INC.                               0.454330
# TIGER GLOBAL MANAGEMENT LLC                     1.622038
# BERKSHIRE HATHAWAY INC                          0.816375
# Algo 1                                          0.186513
# Algo 2                                          0.630263
# S&P 500                                         0.794653
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  1.051613  0.264131  0.744362
# PAULSON & CO.INC.                          0.676589  0.196642  0.543035
# TIGER GLOBAL MANAGEMENT LLC                0.816375  0.186513  0.630263
# BERKSHIRE HATHAWAY INC                     2.280977  0.392920  1.013514
# Algo 1                                     0.392920  0.793637  0.250437
# Algo 2                                     1.013514  0.250437  0.951169
# S&P 500                                    1.134789  0.248991  0.837535
#
#                               S&P 500
# SOROS FUND MANAGEMENT LLC    0.773375
# PAULSON & CO.INC.            0.549886
# TIGER GLOBAL MANAGEMENT LLC  0.794653
# BERKSHIRE HATHAWAY INC       1.134789
# Algo 1                       0.248991
# Algo 2                       0.837535
# S&P 500                      1.000000

# %%
beta_df.plot(figsize=(20,10))

# %%
# Construct a correlation table
corr_df = combined_df.corr()
corr_df
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# Algo 2                                          0.507414
# S&P 500                                         0.623946
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754360  0.321211  0.826873
# PAULSON & CO.INC.                          0.545623  0.268840  0.678152
# TIGER GLOBAL MANAGEMENT LLC                0.424423  0.164387  0.507414
# BERKSHIRE HATHAWAY INC                     1.000000  0.292033  0.688082
# Algo 1                                     0.292033  1.000000  0.288243
# Algo 2                                     0.688082  0.288243  1.000000
# S&P 500                                    0.751371  0.279494  0.858764
#
#                               S&P 500
# SOROS FUND MANAGEMENT LLC    0.837864
# PAULSON & CO.INC.            0.669732
# TIGER GLOBAL MANAGEMENT LLC  0.623946
# BERKSHIRE HATHAWAY INC       0.751371
# Algo 1                       0.279494
# Algo 2                       0.858764
# S&P 500                      1.000000

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)
# YOUR CODE HERE

# %% [markdown]
# ### Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rollwing window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the `ewm` with a 21 day half-life.

# %%
# (OPTIONAL) YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# Calculate and plot the annualized Sharpe ratios for all portfolios to determine which portfolio has the best performance

# %%
# Annualized Sharpe Ratios
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# dtype: float64

# %% [markdown]
#  plot() these sharpe ratios using a barplot.
#  On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales?

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
# YOUR CODE HERE
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
# Read the second stock
# YOUR CODE HERE
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   AAPL  188.59
# 2018-05-14   AAPL  188.15
# 2018-05-15   AAPL  186.44
# 2018-05-16   AAPL  188.18
# 2018-05-17   AAPL  186.99

# %%
# Read the third stock
# YOUR CODE HERE
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   COST  195.76
# 2018-05-14   COST  195.88
# 2018-05-15   COST  195.48
# 2018-05-16   COST  198.71
# 2018-05-17   COST  199.60

# %%
# Concatenate all stocks into a single DataFrame
# YOUR CODE HERE
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
# Reset the index
# YOUR CODE HERE
# Out:
#   Trade DATE Symbol     NOCP
# 0 2018-05-11   GOOG  1098.26
# 1 2018-05-14   GOOG  1100.20
# 2 2018-05-15   GOOG  1079.23
# 3 2018-05-16   GOOG  1081.77
# 4 2018-05-17   GOOG  1078.59

# %%
# Pivot so that each column of prices represents a unique symbol
# YOUR CODE HERE
# Out:
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Drop Nulls
# YOUR CODE HERE
# Out:
# Symbol          AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
# YOUR CODE HERE
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %% [markdown]
# ## Join your custom portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns
# YOUR CODE HERE
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2   S&P 500    Custom
# Date
# 2019-04-16  0.002899  0.000509  0.000340
# 2019-04-17 -0.005228 -0.002274  0.009292
# 2019-04-18 -0.001229  0.001579  0.001545
# 2019-04-22 -0.001936  0.001012  0.001217
# 2019-04-23  0.009622  0.008841  0.011959

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
# YOUR CODE HERE

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      0.146675
# PAULSON & CO.INC.              0.116732
# TIGER GLOBAL MANAGEMENT LLC    0.232531
# BERKSHIRE HATHAWAY INC         0.247155
# Algo 1                         0.133704
# Algo 2                         0.139556
# S&P 500                        0.152054
# Custom                         0.211496
# dtype: float64

# %%
# Rolling
# YOUR CODE HERE

# %%
# Beta
# YOUR CODE HERE

# %%
# Annualized Sharpe Ratios
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      0.430713
# PAULSON & CO.INC.              0.258738
# TIGER GLOBAL MANAGEMENT LLC   -1.034216
# BERKSHIRE HATHAWAY INC         0.159756
# Algo 1                         2.035665
# Algo 2                         0.080607
# S&P 500                        0.584820
# Custom                         0.933123
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE

# %% [markdown]
# ## Include correlation analysis to determine which stocks (if any) are correlated

# %%
# YOUR CODE HERE
# Out:
# <style  type="text/css" >
#     #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow0_col1 {
#             background-color:  #acd666;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow0_col2 {
#             background-color:  #69b466;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow0_col3 {
#             background-color:  #badc66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow0_col4 {
#             background-color:  #40a066;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow0_col5 {
#             background-color:  #c8e366;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow0_col6 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow0_col7 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow1_col0 {
#             background-color:  #afd766;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow1_col2 {
#             background-color:  #6bb566;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow1_col3 {
#             background-color:  #7bbd66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow1_col4 {
#             background-color:  #47a366;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow1_col5 {
#             background-color:  #a8d366;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow1_col6 {
#             background-color:  #abd566;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow1_col7 {
#             background-color:  #84c266;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow2_col0 {
#             background-color:  #369a66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow2_col1 {
#             background-color:  #319866;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow2_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow2_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow2_col5 {
#             background-color:  #118866;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow2_col6 {
#             background-color:  #45a266;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow2_col7 {
#             background-color:  #2d9666;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow3_col0 {
#             background-color:  #b9dc66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow3_col1 {
#             background-color:  #74ba66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow3_col2 {
#             background-color:  #3c9e66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow3_col4 {
#             background-color:  #3d9e66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow3_col5 {
#             background-color:  #a8d366;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow3_col6 {
#             background-color:  #cae466;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow3_col7 {
#             background-color:  #bbdd66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow4_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow4_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow4_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow5_col0 {
#             background-color:  #cae466;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow5_col1 {
#             background-color:  #a9d466;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow5_col2 {
#             background-color:  #55aa66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow5_col3 {
#             background-color:  #add666;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow5_col4 {
#             background-color:  #48a366;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow5_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow5_col6 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow5_col7 {
#             background-color:  #a5d266;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow6_col0 {
#             background-color:  #d0e866;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow6_col1 {
#             background-color:  #a2d066;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow6_col2 {
#             background-color:  #69b466;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow6_col3 {
#             background-color:  #c7e366;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow6_col4 {
#             background-color:  #329866;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow6_col5 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow6_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow6_col7 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow7_col0 {
#             background-color:  #98cc66;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow7_col1 {
#             background-color:  #71b866;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow7_col2 {
#             background-color:  #50a866;
#             color:  #000000;
#         }    #T_f941b0a8_7ae1_11ea_998d_8c859048c80erow7_col3 {
#             background-color:  #b4da66;
#             color:  #000000;
